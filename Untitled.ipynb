# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx

import matplotlib.pyplot as plt

# %%
#!python -m spacy download en_core_web_sm
spacy.cli.download("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 393.8 kB/s eta 0:00:33
#      --------------------------------------- 0.1/12.8 MB 491.5 kB/s eta 0:00:26
#      --------------------------------------- 0.1/12.8 MB 774.0 kB/s eta 0:00:17
#       --------------------------------------- 0.3/12.8 MB 1.3 MB/s eta 0:00:10
#      - -------------------------------------- 0.5/12.8 MB 2.0 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/12.8 MB 2.8 MB/s eta 0:00:05
#      --- ------------------------------------ 1.3/12.8 MB 3.9 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.8/12.8 MB 4.7 MB/s eta 0:00:03
#      ------ --------------------------------- 2.2/12.8 MB 5.3 MB/s eta 0:00:03
#      -------- ------------------------------- 2.6/12.8 MB 5.6 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 6.0 MB/s eta 0:00:02
#      ----------- ---------------------------- 3.5/12.8 MB 6.3 MB/s eta 0:00:02
#      ------------ --------------------------- 4.0/12.8 MB 6.6 MB/s eta 0:00:02
#      -------------- ------------------------- 4.5/12.8 MB 7.0 MB/s eta 0:00:02
#      --------------- ------------------------ 5.0/12.8 MB 7.2 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.4/12.8 MB 7.4 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 7.6 MB/s eta 0:00:01
#      ------------------- -------------------- 6.4/12.8 MB 7.8 MB/s eta 0:00:01
#      --------------------- ------------------ 6.8/12.8 MB 7.9 MB/s eta 0:00:01
#      ---------------------- ----------------- 7.2/12.8 MB 8.0 MB/s eta 0:00:01
#      ------------------------ --------------- 7.8/12.8 MB 8.1 MB/s eta 0:00:01
#      ------------------------- -------------- 8.2/12.8 MB 8.2 MB/s eta 0:00:01
#      --------------------------- ------------ 8.7/12.8 MB 8.3 MB/s eta 0:00:01
#      ---------------------------- ----------- 9.1/12.8 MB 8.4 MB/s eta 0:00:01
#      ----------------------------- ---------- 9.5/12.8 MB 8.4 MB/s eta 0:00:01
#      ------------------------------ --------- 9.9/12.8 MB 8.6 MB/s eta 0:00:01
#      -------------------------------- ------- 10.3/12.8 MB 9.6 MB/s eta 0:00:01
#      -------------------------------- ------ 10.8/12.8 MB 10.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.3/12.8 MB 10.4 MB/s eta 0:00:01
#      ----------------------------------- --- 11.7/12.8 MB 10.4 MB/s eta 0:00:01
#      ------------------------------------- - 12.2/12.8 MB 10.6 MB/s eta 0:00:01
#      --------------------------------------  12.7/12.8 MB 10.6 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 10.6 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 9.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\caoco\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.1.8 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.1)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\caoco\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.24.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\caoco\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\caoco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\caoco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\caoco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\caoco\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\caoco\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\caoco\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.1.8->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\caoco\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\caoco\anaconda3\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\caoco\anaconda3\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\caoco\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English languague model
NER = spacy.load("en_core_web_sm")

# %%
import os
 
# Get all book files in the data directory
books = 'new_testment.txt'
all_books = open(books, encoding="utf8").read()
book_doc = NER(all_books)

# %%
displacy.render(book_doc[0:20000], style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matthew 1:1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 	The book of the lineage of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jesus Christ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the son of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the son of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abraham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matthew 1:2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Abraham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  conceived
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isaac
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . And
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Isaac
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  conceived
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jacob
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . And
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jacob
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  conceived
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Judah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and his brothers.<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matthew 1:3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 	And
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Judah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  conceived
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Perez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zerah
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  by
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tamar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . And
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Perez
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  conceived Hezron. And
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hezron
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  conceived Ram.<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matthew 1:4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 	And Ram conceived
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amminadab
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# . And
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Amminadab
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  conceived
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nahshon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . And
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nahshon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  conceived
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Salmon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .<br>
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Matthew 1:5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# 	And
# <mark class="entity" style="background: #aa9cfc; p

# %%
book_doc.ents
# Out:
# (Matthew 1:1,
#  Jesus Christ,
#  David,
#  Abraham,
#  Matthew 1:2	,
#  Abraham,
#  Isaac,
#  Isaac,
#  Jacob,
#  Jacob,
#  Judah,
#  Matthew 1:3,
#  Judah,
#  Perez,
#  Zerah,
#  Tamar,
#  Perez,
#  Hezron,
#  Matthew 1:4,
#  Amminadab,
#  Amminadab,
#  Nahshon,
#  Nahshon,
#  Salmon,
#  Matthew 1:5,
#  Salmon,
#  Boaz,
#  Rahab,
#  Boaz,
#  Ruth,
#  Obed,
#  Jesse,
#  Matthew 1:6,
#  Jesse,
#  David,
#  David,
#  Solomon,
#  Uriah,
#  Matthew 1:7,
#  Solomon,
#  Rehoboam,
#  Rehoboam,
#  Abijah,
#  Abijah,
#  Matthew 1:8,
#  Joram,
#  Joram,
#  Matthew 1:9,
#  Uzziah,
#  Jotham,
#  Jotham,
#  Ahaz,
#  Ahaz,
#  Hezekiah,
#  Matthew 1:10,
#  Hezekiah,
#  Manasseh,
#  Amos,
#  Amos,
#  Josiah,
#  Matthew 1:11,
#  Josiah,
#  Jechoniah,
#  Babylon,
#  Matthew 1:12,
#  Babylon,
#  Jechoniah,
#  Shealtiel,
#  Zerubbabel,
#  Matthew 1:13,
#  Zerubbabel,
#  Abiud,
#  Abiud,
#  Eliakim,
#  Eliakim,
#  Matthew 1:14,
#  Azor,
#  Zadok,
#  Zadok,
#  Achim,
#  Eliud,
#  Matthew 1:15,
#  Eliud,
#  Eleazar,
#  Eleazar,
#  Matthan,
#  Matthan,
#  Jacob,
#  Matthew 1:16,
#  Jacob,
#  Joseph,
#  Mary,
#  Jesus,
#  Matthew 1:17,
#  Abraham,
#  David,
#  fourteen,
#  David,
#  Babylon,
#  fourteen,
#  Babylon,
#  fourteen,
#  Matthew 1:18,
#  Mary,
#  Joseph,
#  Matthew 1:19,
#  Joseph,
#  Matthew 1:20,
#  Angel,
#  Joseph,
#  David,
#  Mary,
#  Matthew 1:21,
#  Matthew 1:22,
#  Matthew 1:23,
#  Behold,
#  Emmanuel,
#  Matthew 1:24,
#  Joseph,
#  Matthew 1:25,
#  JESUS,
#  Matthew 2:1,
#  Jesus,
#  Bethlehem,
#  Judah,
#  the days,
#  Herod,
#  Magi,
#  Jerusalem,
#  Matthew 2:2,
#  Jews,
#  Matthew 2:3,
#  Herod,
#  Jerusalem,
#  Matthew 2:4,
#  Matthew 2:5,
#  Judea,
#  Matthew 2:6,
#  Bethlehem,
#  Judah,
#  Judah,
#  Israel,
#  Matthew 2:7,
#  Herod,
#  Magi,
#  Matthew 2:8,
#  Bethlehem,
#  Matthew 2:9,
#  Matthew 2:10,
#  Matthew 2:11,
#  Mary,
#  myrrh,
#  Matthew 2:12,
#  Herod,
#  Matthew 2:13,
#  Angel,
#  Joseph,
#  Egypt,
#  Herod,
#  Matthew 2:14,
#  night,
#  Egypt,
#  Matthew 2:15,
#  Herod,
#  Egypt,
#  Matthew 2:16,
#  Herod,
#  Magi,
#  Bethlehem,
#  two years of age,
#  Magi,
#  Matthew 2:17,
#  Matthew 2:18,
#  Ramah,
#  Matthew 2:19,
#  Herod,
#  Angel,
#  Joseph,
#  Egypt,
#  Matthew 2:20,
#  Israel,
#  Matthew 2:21,
#  Israel,
#  Matthew 2:22,
#  Archelaus,
#  Judea,
#  Herod,
#  Galilee,
#  Matthew 2:23,
#  Nazareth,
#  Nazarene,
#  Matthew 3:1,
#  those days,
#  John the Baptist,
#  Judea,
#  Matthew 3:2,
#  Matthew 3:3,
#  Isaiah,
#  Matthew 3:4,
#  John,
#  Matthew 3:5,
#  Jerusalem,
#  Judea,
#  Jordan,
#  Matthew 3:6,
#  Jordan,
#  Matthew 3:7,
#  Matthew 3:8	Therefore,
#  Matthew 3:9,
#  Abraham,
#  Abraham,
#  Matthew 3:10,
#  Matthew 3:11,
#  Matthew 3:12,
#  Matthew 3:13,
#  Jesus,
#  Galilee,
#  John,
#  Jordan,
#  Matthew 3:14,
#  John,
#  Matthew 3:15,
#  Jesus,
#  Matthew 3:16,
#  Jesus,
#  Matthew 3:17,
#  Son,
#  Matthew 4:1,
#  Jesus,
#  Spirit,
#  Matthew 4:2,
#  forty days,
#  forty nights,
#  Matthew 4:3,
#  Matthew 4:4,
#  Matthew 4:5,
#  Matthew 4:6,
#  Matthew 4:7,
#  Jesus,
#  Matthew 4:8	Again,
#  Matthew 4:9,
#  Matthew 4:10,
#  Jesus,
#  Satan,
#  Matthew 4:11,
#  Angels,
#  Matthew 4:12,
#  Jesus,
#  John,
#  Galilee,
#  Matthew 4:13,
#  Nazareth,
#  Capernaum,
#  Zebulun,
#  Naphtali,
#  Matthew 4:14,
#  Isaiah,
#  Matthew 4:15,
#  Land of Zebulun,
#  Naphtali,
#  Jordan,
#  Galilee,
#  Gentiles,
#  Matthew 4:16,
#  Matthew 4:17,
#  Jesus,
#  Matthew 4:18,
#  Jesus,
#  the Sea of Galilee,
#  two,
#  Simon,
#  Peter,
#  Andrew,
#  Matthew 4:19,
#  Matthew 4:20,
#  Matthew 4:21,
#  two,
#  James of Zebedee,
#  John,
#  Zebedee,
#  Matthew 4:22,
#  Matthew 4:23,
#  Jesus,
#  Galilee,
#  Matthew 4:24,
#  Syria,
#  Matthew 4:25,
#  Galilee,
#  Ten,
#  Jerusalem,
#  Judea,
#  Jordan,
#  Matthew 5:1,
#  Matthew 5:2,
#  Matthew 5:3,
#  Matthew 5:4,
#  earth,
#  Matthew 5:5,
#  Matthew 5:6,
#  Matthew 5:7,
#  Matthew 5:8,
#  Matthew 5:9,
#  Matthew 5:10,
#  Matthew 5:11,
#  Matthew 5:12,
#  Matthew 5:13,
#  earth,
#  Matthew 5:14,
#  Matthew 5:15,
#  Matthew 5:16,
#  Matthew 5:17,
#  Matthew 5:18,
#  one,
#  one,
#  Matthew 5:19,
#  one,
#  one,
#  Matthew 5:20,
#  Matthew 5:21,
#  Matthew 5:22,
#  Matthew 5:23,
#  Matthew 5:24,
#  first,
#  Matthew 5:25,
#  Matthew 5:26,
#  the last quarter,
#  Matthew 5:27,
#  Matthew 5:28,
#  Matthew 5:29,
#  Matthew 5:30,
#  Matthew 5:31,
#  Matthew 5:32,
#  Matthew 5:33,
#  Matthew 5:34,
#  Matthew 5:35,
#  Jerusalem,
#  Matthew 5:36,
#  Matthew 5:37,
#  Matthew 5:38,
#  Matthew 5:39,
#  Matthew 5:40,
#  Matthew 5:41,
#  one thousand,
#  two thousand,
#  Matthew 5:42,
#  Matthew 5:43,
#  Matthew 5:44,
#  Matthew 5:45,
#  Matthew 5:46,
#  Matthew 5:47,
#  Matthew 5:48,
#  Matthew 6:1,
#  Matthew 6:2,
#  Matthew 6:3,
#  Matthew 6:4,
#  Matthew 6:5,
#  Matthew 6:6,
#  Matthew 6:7,
#  Matthew 6:8	Therefore,
#  Matthew 6:9	Therefore,
#  Matthew 6:10,
#  May,
#  earth,
#  Matthew 6:11	Give,
#  this day,
#  Matthew 6:12,
#  Matthew 6:13,
#  Matthew 6:14,
#  Matthew 6:15,
#  Matthew 6:16,
#  Matthew 6:17,
#  Matthew 6:18,
#  Matthew 6:19,
#  moth consume,
#  Matthew 6:20,
#  Matthew 6:21,
#  Matthew 6:22,
#  Matthew 6:23,
#  Matthew 6:24,
#  two,
#  Matthew 6:25,
#  Matthew 6:26,
#  Matthew 6:27,
#  Matthew 6:28,
#  Matthew 6:29,
#  Solomon,
#  Matthew 6:30,
#  today,
#  tomorrow,
#  Matthew 6:31	,
#  Matthew 6:32,
#  Gentiles,
#  Matthew 6:33,
#  first,
#  Matthew 6:34,
#  tomorrow,
#  the future day,
#  the day,
#  Matthew 7:1,
#  Matthew 7:2,
#  Matthew 7:3,
#  Matthew 7:4,
#  Matthew 7:5	Hypocrite,
#  first,
#  Matthew 7:6,
#  Matthew 7:7	Ask,
#  Matthew 7:8,
#  Matthew 7:9	Or,
#  Matthew 7:10,
#  Matthew 7:11,
#  Matthew 7:12,
#  Matthew 7:13,
#  Matthew 7:14,
#  Matthew 7:15,
#  Matthew 7:16,
#  Matthew 7:17,
#  Matthew 7:18,
#  Matthew 7:19,
#  Matthew 7:20,
#  Matthew 7:21,
#  Matthew 7:22,
#  that day,
#  Matthew 7:23,
#  Matthew 7:24,
#  Matthew 7:25,
#  Matthew 7:26,
#  Matthew 7:27,
#  Matthew 7:28,
#  Jesus,
#  Matthew 7:29,
#  Pharisees,
#  Matthew 8:1,
#  Matthew 8:2,
#  Matthew 8:3,
#  Jesus,
#  Matthew 8:4,
#  Jesus,
#  Matthew 8:5,
#  Capernaum,
#  Matthew 8:6,
#  Matthew 8:7,
#  Jesus,
#  Matthew 8:8,
#  Matthew 8:9,
#  Matthew 8:10,
#  Jesus,
#  Israel,
#  Matthew 8:11,
#  Abraham,
#  Isaac,
#  Jacob,
#  Matthew 8:12,
#  Matthew 8:13,
#  Jesus,
#  that very hour,
#  Matthew 8:14,
#  Jesus,
#  Peter,
#  Matthew 8:15,
#  Matthew 8:16,
#  evening,
#  Matthew 8:17,
#  Isaiah,
#  Matthew 8:18,
#  Jesus,
#  Matthew 8:19,
#  one,
#  Matthew 8:20,
#  Jesus,
#  Matthew 8:21,
#  first,
#  Matthew 8:22,
#  Jesus,
#  Matthew 8:23,
#  Matthew 8:24,
#  Matthew 8:25,
#  Matthew 8:26,
#  Jesus,
#  Matthew 8:27,
#  Matthew 8:28,
#  Gerasenes,
#  two,
#  Matthew 8:29,
#  O Jesus,
#  Matthew 8:30,
#  Matthew 8:31,
#  Matthew 8:32,
#  Matthew 8:33,
#  Matthew 8:34,
#  Jesus,
#  Matthew 9:1,
#  Matthew 9:2,
#  Jesus,
#  Matthew 9:3,
#  Matthew 9:4,
#  Jesus,
#  Matthew 9:5,
#  Matthew 9:6,
#  Matthew 9:7,
#  Matthew 9:8,
#  Matthew 9:9,
#  Jesus,
#  Matthew,
#  Matthew 9:10,
#  Jesus,
#  Matthew 9:11,
#  Pharisees,
#  Matthew 9:12,
#  Jesus,
#  Matthew 9:13,
#  Matthew 9:14,
#  John,
#  Pharisees,
#  Matthew 9:15,
#  Jesus,
#  the days,
#  Matthew 9:16,
#  Matthew 9:17,
#  Matthew 9:18,
#  Matthew 9:19,
#  Jesus,
#  Matthew 9:20,
#  twelve years,
#  Matthew 9:21,
#  Matthew 9:22,
#  Jesus,
#  that hour,
#  Matthew 9:23,
#  Jesus,
#  Matthew 9:24,
#  Matthew 9:25,
#  Matthew 9:26,
#  Matthew 9:27,
#  Jesus,
#  two,
#  Son,
#  David,
#  Matthew 9:28,
#  Jesus,
#  Certainly, Lord,
#  Matthew 9:29,
#  Matthew 9:30,
#  Jesus,
#  Matthew 9:31,
#  Matthew 9:32,
#  Matthew 9:33,
#  Israel,
#  Matthew 9:34,
#  Pharisees,
#  Matthew 9:35,
#  Jesus,
#  Matthew 9:36,
#  Matthew 9:37,
#  Matthew 9:38,
#  Matthew 10:1,
#  twelve,
#  Matthew 10:2,
#  twelve,
#  First,
#  Simon,
#  Peter,
#  Andrew,
#  Matthew 10:3,
#  James of Zebedee,
#  John,
#  Philip,
#  Bartholomew,
#  Thomas,
#  Matthew,
#  James of Alphaeus,
#  Thaddaeus,
#  Matthew 10:4,
#  Simon the Canaanite,
#  Judas Iscariot,
#  Matthew 10:5,
#  Jesus,
#  twelve,
#  Gentiles,
#  Matthew 10:6,
#  Israel,
#  Matthew 10:7,
#  Matthew 10:8,
#  Matthew 10:9,
#  Matthew 10:10,
#  two,
#  Matthew 10:11,
#  Matthew 10:12,
#  Matthew 10:13,
#  Matthew 10:14,
#  Matthew 10:15,
#  Sodom,
#  Gomorrah,
#  the day,
#  Matthew 10:16,
#  Behold,
#  Matthew 10:17,
#  Matthew 10:18,
#  Gentiles,
#  Matthew 10:19,
#  that hour,
#  Matthew 10:20,
#  Spirit,
#  Matthew 10:21,
#  Matthew 10:22,
#  Matthew 10:23,
#  one,
#  Israel,
#  Matthew 10:24,
#  Matthew 10:25,
#  Matthew 10:26,
#  Matthew 10:27,
#  Matthew 10:28,
#  Matthew 10:29,
#  two,
#  one,
#  one,
#  Matthew 10:30,
#  Matthew 10:31,
#  Matthew 10:32,
#  Matthew 10:33,
#  Matthew 10:34,
#  earth,
#  Matthew 10:35,
#  Matthew 10:36,
#  Matthew 10:37,
#  Matthew 10:38,
#  Matthew 10:39,
#  Matthew 10:40,
#  Matthew 10:41,
#  Matthew 10:42,
#  one,
#  Matthew 11:1,
#  Jesus,
#  twelve,
#  Matthew 11:2,
#  John,
#  two,
#  Matthew 11:3,
#  Matthew 11:4,
#  Jesus,
#  John,
#  Matthew 11:5,
#  Matthew 11:6,
#  Matthew 11:7,
#  Jesus,
#  John,
#  Matthew 11:8,
#  Behold,
#  Matthew 11:9,
#  Matthew 11:10,
#  Angel,
#  Matthew 11:11,
#  John,
#  Matthew 11:12,
#  the days,
#  John the Baptist,
#  Matthew 11:13,
#  John,
#  Matthew 11:14,
#  Elijah,
#  Matthew 11:15,
#  Matthew 11:16,
#  Matthew 11:17,
#  Matthew 11:18,
#  John,
#  Matthew 11:19,
#  Matthew 11:20,
#  Matthew 11:21,
#  Chorazin,
#  Bethsaida,
#  Tyre,
#  Sidon,
#  Matthew 11:22,
#  Tyre,
#  Sidon,
#  the day,
#  Matthew 11:23,
#  Capernaum,
#  Sodom,
#  this day,
#  Matthew 11:24,
#  Sodom,
#  the day,
#  Matthew 11:25,
#  Jesus,
#  Matthew 11:26,
#  Matthew 11:27,
#  Son,
#  Son,
#  Matthew 11:28,
#  Matthew 11:29,
#  Matthew 11:30,
#  Matthew 12:1,
#  Jesus,
#  Sabbath,
#  Matthew 12:2,
#  Behold,
#  Sabbaths,
#  Matthew 12:3,
#  David,
#  Matthew 12:4,
#  Presence,
#  Matthew 12:5	,
#  Sabbaths,
#  Sabbath,
#  Matthew 12:6,
#  Matthew 12:7,
#  Matthew 12:8,
#  Sabbath,
#  Matthew 12:9,
#  Matthew 12:10,
#  Sabbaths,
#  Matthew 12:11,
#  one,
#  Sabbath,
#  Matthew 12:12,
#  Sabbaths,
#  Matthew 12:13,
#  Matthew 12:14,
#  Pharisees,
#  Matthew 12:15,
#  Jesus,
#  Matthew 12:16,
#  Matthew 12:17,
#  Isaiah,
#  Matthew 12:18,
#  Behold,
#  Spirit,
#  Matthew 12:19,
#  Matthew 12:20,
#  Matthew 12:21,
#  Gentiles,
#  Matthew 12:22,
#  Matthew 12:23,
#  David,
#  Matthew 12:24,
#  Beelzebub,
#  Matthew 12:25,
#  Jesus,
#  Matthew 12:26,
#  Satan,
#  Satan,
#  Matthew 12:27,
#  Beelzebub,
#  Matthew 12:28,
#  Matthew 12:29,
#  first,
#  Matthew 12:30,
#  Matthew 12:31,
#  Spirit,
#  Matthew 12:32,
#  Matthew 12:33,
#  Matthew 12:34,
#  Progeny,
#  Matthew 12:35,
#  Matthew 12:36,
#  the day,
#  Matthew 12:37,
#  Matthew 12:38,
#  Pharisees,
#  Matthew 12:39,
#  Jonah,
#  Matthew 12:40,
#  Jonah,
#  three days,
#  three nights,
#  three days,
#  three nights,
#  Matthew 12:41,
#  Nineveh,
#  Jonah,
#  Jonah,
#  Matthew 12:42,
#  The Queen of the South,
#  Solomon,
#  Solomon,
#  Matthew 12:43,
#  Matthew 12:44,
#  Matthew 12:45,
#  seven,
#  first,
#  Matthew 12:46,
#  Matthew 12:47,
#  Matthew 12:48,
#  Matthew 12:49,
#  Matthew 12:50,
#  Matthew 13:1,
#  that day,
#  Jesus,
#  Matthew 13:2,
#  Matthew 13:3,
#  Behold,
#  Matthew 13:4,
#  Matthew 13:5,
#  Matthew 13:6,
#  Matthew 13:7,
#  Matthew 13:8,
#  some one hundred fold,
#  some sixty fold,
#  some thirty,
#  Matthew 13:9,
#  Matthew 13:10,
#  Matthew 13:11,
#  Matthew 13:12,
#  Matthew 13:13,
#  Matthew 13:14,
#  Isaiah,
#  Matthew 13:15,
#  Matthew 13:16,
#  Matthew 13:17,
#  Matthew 13:18,
#  Matthew 13:19,
#  Matthew 13:20,
#  Matthew 13:21,
#  Matthew 13:22,
#  Matthew 13:23,
#  some a hundred fold,
#  another sixty fold,
#  another thirty fold,
#  Matthew 13:24,
#  Matthew 13:25,
#  Matthew 13:26,
#  Matthew 13:27,
#  Matthew 13:28,
#  Matthew 13:29,
#  Matthew 13:30,
#  first,
#  Matthew 13:31,
#  Matthew 13:32,
#  Matthew 13:33,
#  three,
#  Matthew 13:34,
#  Jesus,
#  Matthew 13:35,
#  Matthew 13:36,
#  Matthew 13:37,
#  Matthew 13:38,
#  Matthew 13:39,
#  Angels,
#  Matthew 13:40	Therefore,
#  Matthew 13:41,
#  Angels,
#  Matthew 13:42,
#  Matthew 13:43,
#  Matthew 13:44,
#  Matthew 13:45,
#  Matthew 13:46,
#  one,
#  Matthew 13:47	Again,
#  Matthew 13:48,
#  Matthew 13:49,
#  Angels,
#  Matthew 13:50,
#  Matthew 13:51,
#  Matthew 13:52,
#  Matthew 13:53,
#  Jesus,
#  Matthew 13:54,
#  Matthew 13:55,
#  Mary,
#  James,
#  Joseph,
#  Simon,
#  Jude,
#  Matthew 13:56,
#  Matthew 13:57,
#  Jesus,
#  Matthew 13:58,
#  Matthew 14:1,
#  Herod,
#  Tetrarch,
#  Jesus,
#  Matthew 14:2,
#  John the Baptist,
#  Matthew 14:3,
#  Herod,
#  John,
#  Herodias,
#  Matthew 14:4,
#  John,
#  Matthew 14:5,
#  Matthew 14:6,
#  Herod,
#  Herodias,
#  Herod,
#  Matthew 14:7,
#  Matthew 14:8,
#  John the Baptist,
#  Matthew 14:9,
#  Matthew 14:10,
#  John,
#  Matthew 14:11,
#  Matthew 14:12,
#  Jesus,
#  Matthew 14:13,
#  Jesus,
#  Matthew 14:14,
#  Matthew 14:15,
#  evening,
#  the hour,
#  Matthew 14:16,
#  Jesus,
#  Matthew 14:17,
#  five,
#  two,
#  Matthew 14:18,
#  Matthew 14:19,
#  five,
#  two,
#  Matthew 14:20,
#  twelve,
#  Matthew 14:21,
#  five thousand,
#  Matthew 14:22,
#  Jesus,
#  Matthew 14:23,
#  evening,
#  Matthew 14:24,
#  Matthew 14:25,
#  fourth,
#  Matthew 14:26,
#  Matthew 14:27,
#  Jesus,
#  I.,
#  Matthew 14:28,
#  Peter,
#  Matthew 14:29,
#  Peter,
#  Jesus,
#  Matthew 14:30,
#  Matthew 14:31,
#  Jesus,
#  Matthew 14:32,
#  Matthew 14:33,
#  Matthew 14:34,
#  Genesaret,
#  Matthew 14:35,
#  Matthew 14:36,
#  Matthew 15:1,
#  Pharisees,
#  Jerusalem,
#  Matthew 15:2,
#  Matthew 15:3,
#  God,
#  Matthew 15:4,
#  Matthew 15:5,
#  Matthew 15:6,
#  Matthew 15:7	Hypocrites,
#  Isaiah,
#  Matthew 15:8	‘,
#  Matthew 15:9,
#  Matthew 15:10,
#  Matthew 15:11,
#  Matthew 15:12,
#  Pharisees,
#  Matthew 15:13,
#  Matthew 15:14,
#  Matthew 15:15,
#  Peter,
#  Matthew 15:16,
#  Matthew 15:17,
#  Matthew 15:18,
#  Matthew 15:19,
#  Matthew 15:20,
#  Matthew 15:21,
#  Jesus,
#  Tyre,
#  Sidon,
#  Matthew 15:22,
#  Canaan,
#  Son,
#  David,
#  Matthew 15:23,
#  Matthew 15:24,
#  Israel,
#  Matthew 15:25,
#  Matthew 15:26,
#  Matthew 15:27,
#  Matthew 15:28,
#  Jesus,
#  that very hour,
#  Matthew 15:29,
#  Jesus,
#  Galilee,
#  Matthew 15:30,
#  Matthew 15:31,
#  Israel,
#  Matthew 15:32,
#  Jesus,
#  three days,
#  Matthew 15:33,
#  Matthew 15:34,
#  Jesus,
#  Seven,
#  Matthew 15:35,
#  Matthew 15:36,
#  seven,
#  Matthew 15:37,
#  seven,
#  Matthew 15:38,
#  ...)

# %%
names_list = []
for entity in book_doc.ents:
    if ':' in entity.text:
        continue
    if entity.label_ == 'PERSON':
    
        names_list.append(entity.text)

# %%
len(pd.Series(names_list).value_counts())
# Out:
# 169

# %%
pd.Series(names_list).value_counts().index
# Out:
# Index(['Jesus', 'John', 'Peter', 'Luke', 'Behold', 'Simon', 'Mary', 'Sabbath',
#        'David', 'Pharisees',
#        ...
#        'Mark', 'Thaddeus', 'Abiathar', 'Lo', 'the King of Israel', 'Haceldama',
#        'Jesus the Galilean', 'Gethsemani', 'dumbstruck', 'Mary of Cleophas'],
#       dtype='object', length=169)

# %%
for row, name in enumerate(pd.Series(names_list).value_counts().index):
    print(name)
# Out:
# Jesus
# John
# Peter
# Luke
# Behold
# Simon
# Mary
# Sabbath
# David
# Pharisees
# Son
# Abraham
# Herod
# Joseph
# Elijah
# James
# Simon Peter
# Philip
# Angel
# Martha
# Isaiah
# Jacob
# Pilate
# Galilee
# Andrew
# Thomas
# Mary Magdalene
# Judas
# Barabbas
# Judas Iscariot
# Judea
# Elizabeth
# John the Baptist
# Sidon
# Isaac
# Solomon
# Nazareth
# Jesus of Nazareth
# Hosanna
# Blessed
# Nathanael
# Gospel
# Noah
# Jesus Christ
# Lazarus
# Matthew
# Scriptures
# James of Zebedee
# Herodias
# bush
# James of Alphaeus
# Zacchaeus
# Jude
# Zebedee
# Bartholomew
# Levi
# Boaz
# Amos
# Babylon
# Shepherd
# Zerubbabel
# Jesse
# Eliakim
# Perez
# Nahshon
# Apostles
# Salt
# Simeon
# Hezekiah
# Ahaz
# Jotham
# Joram
# Rehoboam
# Salmon
# Daughter
# Obed
# Caesarea Philippi
# Joanna
# Jairus
# Cyrene
# Josiah
# Abel
# Mattathias
# Bethsaida
# Matthan
# God
# Eleazar
# Eliud
# Olivet
# Abiud
# Zadok
# Jonah
# Siloam
# Gentiles
# Genesaret
# Nineveh
# Terah
# Enoch
# Malchus
# Eber
# Joshua
# Eliezer
# Jorim
# Cephas
# Aram
# Caesar
# Menna
# Samaria
# Melea
# Seth
# Sell
# Adam
# Bethphage
# Prophet
# Elisha
# Naaman
# Nain
# Jesus hid
# Bethania
# Magdalene
# awaken
# Susanna
# John first
# Word
# wolf
# Zachariah
# Mary of James
# Jesus the Christ
# Abilene
# Tyre
# Thaddaeus
# O Jesus
# moth consume
# Nazarene
# Archelaus
# myrrh
# Magi
# JESUS
# Emmanuel
# Achim
# Shealtiel
# Jechoniah
# Uriah
# Ruth
# Rahab
# Zerah
# Judah
# Gomorrah
# Jeremiah
# Phanuel
# rebuke him
# Anna
# Saviour
# Gabriel
# Aaron
# Joseph of Arimathea
# Prophesy
# Arise
# Bartimaeus
# Mark
# Thaddeus
# Abiathar
# Lo
# the King of Israel
# Haceldama
# Jesus the Galilean
# Gethsemani
# dumbstruck
# Mary of Cleophas

# %%
import pandas as pd

# Sample dictionary with names mapping
names_mapping = {
  "Jesus": ["Jesus", "Jesus Christ", "Jesus of Nazareth", "Jesus the Christ", "JESUS", "O Jesus", "Jesus the Galilean", "Nazarene"],
  "John": ["John", "John the Baptist", "John first"],
  "Peter": ["Peter", "Simon Peter", "Cephas"],
  "Mary": ["Mary"],
  "Mary Magdalene": ["Mary Magdalene", "Magdalene"],
  "Mary of James": ["Mary of James", "Mary of Cleophas"],
  "James of Zebedee": ["James of Zebedee", "James of Alphaeus"],
  "Judas": ["Judas"],
  "Judas Iscariot": ["Judas Iscariot"],
  "Joseph": ["Joseph"],
  "Joseph of Arimathea": ["Joseph of Arimathea"],
  "Philip": ["Philip"],
  "Andrew": ["Andrew"],
  "Thomas": ["Thomas"],
  "Martha": ["Martha"],
  "Lazarus": ["Lazarus"],
  "Simon": ["Simon"],
  "Thaddaeus": ["Thaddaeus"],
  "Bartholomew": ["Bartholomew"],
  "Matthew": ["Matthew", "Levi"],
  "Zachariah": ["Zachariah"],
  "Magi": ["Magi"],
  "Gabriel": ["Gabriel"],
  "Elizabeth": ["Elizabeth"],
  "Anna": ["Anna"],
  "Mark": ["Mark"],
  "Nathanael": ["Nathanael"],
  "Simeon": ["Simeon"],
  "Aaron": ["Aaron"],
  "Herod": ["Herod", "Herodias", "Archelaus"],
  "Caesar": ["Caesar"],
  "Jairus": ["Jairus"],
  "Pilate": ["Pilate"],
  "Barabbas": ["Barabbas"],
  "Emmanuel": ["Emmanuel"],
  "Ruth": ["Ruth"],
  "Rahab": ["Rahab"],
  "Bartimaeus": ["Bartimaeus"],
  "Solomon": ["Solomon"],
  "David": ["David"],
  "Abraham": ["Abraham"],
  "Isaac": ["Isaac"],
  "Jacob": ["Jacob"],
  "Moses": ["Moses"],
  "Isaiah": ["Isaiah"],
  "Elijah": ["Elijah"],
  "Elisha": ["Elisha"],
  "Jesse": ["Jesse"],
  "Hezekiah": ["Hezekiah"],
  "Ahaz": ["Ahaz"],
  "Jotham": ["Jotham"],
  "Joram": ["Joram"],
  "Rehoboam": ["Rehoboam"],
  "Salmon": ["Salmon"],
  "Obed": ["Obed"],
  "Perez": ["Perez"],
  "Nahshon": ["Nahshon"],
  "Zerubbabel": ["Zerubbabel"],
  "Zadok": ["Zadok"],
  "Joanna": ["Joanna"],
  "Boaz": ["Boaz"],
  "Joshua": ["Joshua"],
  "Enoch": ["Enoch"],
  "Malchus": ["Malchus"],
  "Jeremiah": ["Jeremiah"],
  "Zerah": ["Zerah"],
  "Judah": ["Judah"],
  "Achim": ["Achim"],
  "Shealtiel": ["Shealtiel"],
  "Jechoniah": ["Jechoniah"],
  "Uriah": ["Uriah"],
  "Phanuel": ["Phanuel"],
  "Zacchaeus": ["Zacchaeus"],
  "Eleazar": ["Eleazar"],
  "Abiud": ["Abiud"],
  "Abiathar": ["Abiathar"],
  "Mattathias": ["Mattathias"],
  "Matthan": ["Matthan"],
  "Aram": ["Aram"],
  "Menna": ["Menna"],
  "Terah": ["Terah"],
  "Eber": ["Eber"],
  "Eliezer": ["Eliezer"],
  "Melea": ["Melea"]
}


# Creating a reverse mapping from each alias to the main name
reverse_mapping = {}
for key, aliases in names_mapping.items():
    for alias in aliases:
        reverse_mapping[alias] = key

# %%
df = pd.DataFrame(names_list, columns=['Name'])
df['Count'] = df.groupby('Name')['Name'].transform('count')
df = df.drop_duplicates()

# Mapping names to their corresponding main names
df['Main Name'] = df['Name'].map(reverse_mapping)

# Grouping by the main name and summing counts
df_grouped = df.groupby('Main Name').agg({'Count': 'sum'}).reset_index()

# Adding a 'First Name' column which is the first word in the 'Main Name'
df_grouped['First Name'] = df_grouped['Main Name'].apply(lambda x: x.split()[0])

# Display the result
df_grouped
# Out:
#      Main Name  Count  First Name
# 0        Aaron      1       Aaron
# 1     Abiathar      1    Abiathar
# 2        Abiud      2       Abiud
# 3      Abraham     34     Abraham
# 4        Achim      1       Achim
# ..         ...    ...         ...
# 78   Zacchaeus      3   Zacchaeus
# 79   Zachariah      1   Zachariah
# 80       Zadok      2       Zadok
# 81       Zerah      1       Zerah
# 82  Zerubbabel      3  Zerubbabel
#
# [83 rows x 3 columns]

# %%
character_df = pd.merge(df_grouped, df['Main Name']).drop_duplicates()
character_df.rename(columns={'Main Name': 'character', 'First Name':'character_firstname'}, inplace=True)

# %%
sent_entity_df = []

# Loop through sentences, store named entity list for each sentence
for sent in book_doc.sents:
    entity_list = [ent.text for ent in sent.ents]
    sent_entity_df.append({"sentence": sent, "entities": entity_list})
    
sent_entity_df = pd.DataFrame(sent_entity_df)

# %%
sent_entity_df
# Out:
#                                                sentence  \
# 0     (Matthew, 1:1, \t, The, book, of, the, lineage...
# 1      (Matthew, 1:2, \t, Abraham, conceived, Isaac, .)
# 2                     (And, Isaac, conceived, Jacob, .)
# 3     (And, Jacob, conceived, Judah, and, his, broth...
# 4     (Matthew, 1:3, \t, And, Judah, conceived, Pere...
# ...                                                 ...
# 6555  (But, Jesus, did, not, say, to, him, that, he,...
# 6556                                  (John, 21:24, \t)
# 6557  (This, is, the, same, disciple, who, offers, t...
# 6558  (And, we, know, that, his, testimony, is, true...
# 6559  (John, 21:25, \t, Now, there, are, also, many,...
#
#                                          entities
# 0     [Matthew 1:1, Jesus Christ, David, Abraham]
# 1                 [Matthew 1:2\t, Abraham, Isaac]
# 2                                  [Isaac, Jacob]
# 3                                  [Jacob, Judah]
# 4       [Matthew 1:3, Judah, Perez, Zerah, Tamar]
# ...                                           ...
# 6555                                      [Jesus]
# 6556                                 [John 21:24]
# 6557                                           []
# 6558                                           []
# 6559                          [John 21:25, Jesus]
#
# [6560 rows x 2 columns]

# %%
# Function to filter out non-character entities
def filter_entity(ent_list, character_df):
    return [ent for ent in ent_list 
            if ent in list(character_df.character) 
            or ent in list(character_df.character_firstname)]

sent_entity_df['character_entities'] = sent_entity_df['entities'].apply(lambda x: filter_entity(x, character_df))

# Filter out sentences that don't have any character entities
sent_entity_df_filtered = sent_entity_df[sent_entity_df['character_entities'].map(len) > 0]
sent_entity_df_filtered.head(10)
# Out:
#                                              sentence  \
# 0   (Matthew, 1:1, \t, The, book, of, the, lineage...
# 1    (Matthew, 1:2, \t, Abraham, conceived, Isaac, .)
# 2                   (And, Isaac, conceived, Jacob, .)
# 3   (And, Jacob, conceived, Judah, and, his, broth...
# 4   (Matthew, 1:3, \t, And, Judah, conceived, Pere...
# 5                  (And, Perez, conceived, Hezron, .)
# 8             (And, Amminadab, conceived, Nahshon, .)
# 9            (And, Nahshon, conceived, Salmon, ., \n)
# 11       (And, Salmon, conceived, Boaz, by, Rahab, .)
# 12          (And, Boaz, conceived, Obed, by, Ruth, .)
#
#                                        entities     character_entities
# 0   [Matthew 1:1, Jesus Christ, David, Abraham]       [David, Abraham]
# 1               [Matthew 1:2\t, Abraham, Isaac]       [Abraham, Isaac]
# 2                                [Isaac, Jacob]         [Isaac, Jacob]
# 3                                [Jacob, Judah]         [Jacob, Judah]
# 4     [Matthew 1:3, Judah, Perez, Zerah, Tamar]  [Judah, Perez, Zerah]
# 5                                       [Perez]                [Perez]
# 8                          [Amminadab, Nahshon]              [Nahshon]
# 9                             [Nahshon, Salmon]      [Nahshon, Salmon]
# 11                        [Salmon, Boaz, Rahab]  [Salmon, Boaz, Rahab]
# 12                                 [Boaz, Ruth]           [Boaz, Ruth]

# %%
sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0] 
                                                                                                               for item in x])
# Out:
# C:\Users\caoco\AppData\Local\Temp\ipykernel_21352\2127265797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sent_entity_df_filtered['character_entities'] = sent_entity_df_filtered['character_entities'].apply(lambda x: [item.split()[0]

# %%
window_size = 5
relationships = []

for i in range(sent_entity_df_filtered.index[-1]):
    end_i = min(i+5, sent_entity_df_filtered.index[-1])
    char_list = sum((sent_entity_df_filtered.loc[i: end_i].character_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#        source   target
# 0       David  Abraham
# 1     Abraham    Isaac
# 2       Isaac    Jacob
# 3       Jacob    Judah
# 4       Judah    Perez
# ...       ...      ...
# 3120    Jesus    Peter
# 3121    Peter    Jesus
# 3122    Peter    Jesus
# 3123    Jesus    Peter
# 3124    Peter    Jesus
#
# [3125 rows x 2 columns]

# %%
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)

# %%
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
# Create a graph from a pandas dataframe
G = nx.from_pandas_edgelist(relationship_df, 
                            source = "source", 
                            target = "target", 
                            edge_attr = "value", 
                            create_using = nx.Graph())

# %%
plt.figure(figsize=(10,10))
pos = nx.kamada_kawai_layout(G)
nx.draw(G, with_labels=True, node_color='skyblue', edge_cmap=plt.cm.Blues, pos = pos)
plt.show()

# %%
from pyvis.network import Network
net = Network(notebook = True, width="1000px", height="700px", bgcolor='#222222', font_color='white')

node_degree = dict(G.degree)

#Setting up node size attribute
nx.set_node_attributes(G, node_degree, 'size')

net.from_nx(G)
net.show("bible.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# bible.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="bible.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
# Degree centrality
degree_dict = nx.degree_centrality(G)
pd.Series(degree_dict).sort_values(ascending=False).head(10)
# Out:
# Jesus     0.415584
# Mary      0.220779
# Joseph    0.194805
# Herod     0.181818
# John      0.155844
# Elijah    0.116883
# David     0.116883
# Peter     0.116883
# Jacob     0.103896
# Judah     0.103896
# dtype: float64

# %%
degree_df = pd.DataFrame.from_dict(degree_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
degree_df.sort_values('centrality', ascending=False)[0:9].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# Betweenness centrality
betweenness_dict = nx.betweenness_centrality(G)
betweenness_df = pd.DataFrame.from_dict(betweenness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
betweenness_df.sort_values('centrality', ascending=False)[0:9].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# Closeness centrality
closeness_dict = nx.closeness_centrality(G)
closeness_df = pd.DataFrame.from_dict(closeness_dict, orient='index', columns=['centrality'])
# Plot top 10 nodes
closeness_df.sort_values('centrality', ascending=False)[0:9].plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# Save centrality measures
nx.set_node_attributes(G, degree_dict, 'degree_centrality')
nx.set_node_attributes(G, betweenness_dict, 'betweenness_centrality')
nx.set_node_attributes(G, closeness_dict, 'closeness_centrality')

# %%
import community as community_louvain

# %%
communities = community_louvain.best_partition(G)
communities
# Out:
# {'Abraham': 0,
#  'David': 0,
#  'Isaac': 0,
#  'Jacob': 0,
#  'Judah': 0,
#  'Perez': 1,
#  'Zerah': 1,
#  'Nahshon': 1,
#  'Salmon': 1,
#  'Boaz': 1,
#  'Rahab': 1,
#  'Ruth': 1,
#  'Obed': 1,
#  'Jesse': 1,
#  'Solomon': 2,
#  'Uriah': 2,
#  'Rehoboam': 2,
#  'Joram': 2,
#  'Jotham': 2,
#  'Ahaz': 2,
#  'Hezekiah': 2,
#  'Jechoniah': 2,
#  'Shealtiel': 2,
#  'Zerubbabel': 4,
#  'Abiud': 4,
#  'Zadok': 4,
#  'Achim': 4,
#  'Eleazar': 4,
#  'Matthan': 4,
#  'Joseph': 0,
#  'Mary': 0,
#  'Jesus': 5,
#  'Emmanuel': 0,
#  'Herod': 0,
#  'Magi': 0,
#  'Isaiah': 6,
#  'John': 6,
#  'Simon': 6,
#  'Peter': 6,
#  'Andrew': 6,
#  'James': 6,
#  'Matthew': 5,
#  'Philip': 6,
#  'Bartholomew': 5,
#  'Thomas': 5,
#  'Thaddaeus': 5,
#  'Judas': 5,
#  'Elijah': 6,
#  'Jeremiah': 6,
#  'Caesar': 5,
#  'Pilate': 5,
#  'Barabbas': 5,
#  'Abiathar': 0,
#  'Jairus': 5,
#  'Mark': 6,
#  'Bartimaeus': 5,
#  'Aaron': 0,
#  'Elizabeth': 0,
#  'Gabriel': 6,
#  'Simeon': 4,
#  'Anna': 0,
#  'Phanuel': 0,
#  'Mattathias': 4,
#  'Joshua': 4,
#  'Eliezer': 4,
#  'Melea': 0,
#  'Menna': 0,
#  'Aram': 1,
#  'Terah': 3,
#  'Eber': 3,
#  'Enoch': 3,
#  'Elisha': 6,
#  'Joanna': 0,
#  'Martha': 0,
#  'Lazarus': 0,
#  'Zacchaeus': 5,
#  'Nathanael': 5,
#  'Malchus': 5}

# %%
nx.set_node_attributes(G, communities, 'group')

# %%
com_net = Network(notebook = True, width="1000px", height="700px", bgcolor='#222222', font_color='white')
com_net.from_nx(G)
com_net.show("bible_communities.html")
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.
# bible_communities.html
#         <iframe
#             width="1000px"
#             height="700px"
#             src="bible_communities.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
com_net.show("bible_communities.pdf")
# Out:
# bible_communities
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 com_net.show("bible_communities")
#
# File ~\anaconda3\Lib\site-packages\pyvis\network.py:546, in Network.show(self, name, local, notebook)
#     544 print(name)
#     545 if notebook:
# --> 546     self.write_html(name, open_browser=False,notebook=True)
#     547 else:
#     548     self.write_html(name, open_browser=True)
#
# File ~\anaconda3\Lib\site-packages\pyvis\network.py:514, in Network.write_html(self, name, local, notebook, open_browser)
#     501 """
#     502 This method gets the data structures supporting the nodes, edges,
#     503 and options and updates the template to write the HTML holding
#    (...)
#     511 @param open_browser: If true, will open a web browser with the generated graph.
#     512 """
#     513 getcwd_name = name
# --> 514 check_html(getcwd_name)
#     515 self.html = self.generate_html(notebook=notebook)
#     517 if self.cdn_resources == "local":
#
# File ~\anaconda3\Lib\site-packages\pyvis\utils.py:11, in check_html(name)
#       4 def check_html(name):
#       5     """
#       6     Given a name of graph to save or write, check if it is of valid syntax
#       7
#       8     :param: name: the name to check
#       9     :type name: str
#      10     """
# ---> 11     assert len(name.split(".")) >= 2, "invalid file type for %s" % name
#      12     assert name.split(
#      13         ".")[-1] == "html", "%s is not a valid html file" % name
#
# AssertionError: invalid file type for bible_communities
